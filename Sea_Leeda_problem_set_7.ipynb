# %%
If you are importing a csv/excel file or using pandas.read_html, then please have the following completed:

 

Attach the CSV file to CANVAS ##

Visualize your dataset with at least 3 visualizations
  A histogram for the features you are interested in
  A scatter plot for any relationships you are interested in (or boxplot if you plan to look at categorical variables)

Start working on your feature engineering
  Show whether or not there are missing data
  Show whether or not there are duplicates
  Show whether or not there are outliers
  List the variables you will be dummy coding

Write a description in a text cell with what you plan to do next. 
Make sure you address 1) how you will handle feature engineering, 2) what kind of analysis you want to do

# %% [markdown]
# Bolded text = **do not change**
#
# Italics text = *replace with your own words*

# %% [markdown]
# ******************
# *******************
#
# # **Description of data**
#
# *Describe your dataset and what you want to analyze*

# %% [markdown]
# *******************
# *******************
# # **Libraries**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# *******************
# *******************
# # **Functions used in notebook**
#
# *If you write a function to help with any of your sections, please put that function here*

# %%
# Functions that you develop

# %% [markdown]
# *******************
# *******************
# # **Getting data**
#
# *Provide Pseudocode*

# %%
# Code for acquiring data
avocado_data = pd.read_csv('avocado.csv')

# %%
# Display first 5 rows of data
avocado_data.head()
# Out:
#    Unnamed: 0        Date  AveragePrice  ...          type  year  region
# 0           0  2015-12-27          1.33  ...  conventional  2015  Albany
# 1           1  2015-12-20          1.35  ...  conventional  2015  Albany
# 2           2  2015-12-13          0.93  ...  conventional  2015  Albany
# 3           3  2015-12-06          1.08  ...  conventional  2015  Albany
# 4           4  2015-11-29          1.28  ...  conventional  2015  Albany
#
# [5 rows x 14 columns]

# %%
# Display last 5 rows of data
avocado_data.tail()
# Out:
#        Unnamed: 0        Date  AveragePrice  ...     type  year            region
# 18244           7  2018-02-04          1.63  ...  organic  2018  WestTexNewMexico
# 18245           8  2018-01-28          1.71  ...  organic  2018  WestTexNewMexico
# 18246           9  2018-01-21          1.87  ...  organic  2018  WestTexNewMexico
# 18247          10  2018-01-14          1.93  ...  organic  2018  WestTexNewMexico
# 18248          11  2018-01-07          1.62  ...  organic  2018  WestTexNewMexico
#
# [5 rows x 14 columns]

# %%
# Show data.info

# %%
# Show data.describe

# %% [markdown]
# ***************
# ***************
# # **Visualizing data**
#
# *Provide relevant pseudocode*

# %%
# visualization 1
sns.distplot(avocado_data['AveragePrice'],kde=False)    # histogram visualization
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# visualization 2
sns.distplot(avocado_data['Total Bags'],kde=False)      # histogram visualization 
plt.xlim([0,1000000])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# (0.0, 1000000.0)

# %%
# visualization 3
sns.scatterplot(avocado_data['Date'],avocado_data['AveragePrice'])      # scatterplot visualization
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
# visualization 4

# %%
# visualization 5

# %%
# visualization 6

# %% [markdown]
# ***************
# ***************
# # **Feature Engineering**
#
# *If making specific choices (e.g., binning data, dummy coding, etc), please describe what you plan to do here*
#
# *Provide relevant pseudocode*

# %%
# Check and take care of null values
# Show whether or not there are missing data
sns.heatmap(avocado_data.isnull(),cmap=['Green', 'Red'])     
# There are no null values in the data set

# %%
# Show whether or not there are duplicates
any(avocado_data.duplicated())
# Out:
# False

# %%
# Check and take care of string values

# %%
# Check and take care of outliers
# Show whether or not there are outliers

fig,axes = plt.subplots(9,1,figsize=(12,12))

count = 0
for column in avocado_data.columns:
  if isinstance(avocado_data[column][0],float)==1:
    sns.boxplot(x = avocado_data[column],ax=axes[count])
    count = count + 1

plt.tight_layout()

# %%
# Any additional feature engineering

# %% [markdown]
# ## The variables that will be dummy coded are type and year.

# %% [markdown]
# ## What I plan to do next
#
# I plan to ask the professor or one of the TAs whether I should remove the outliers for the average price column or not. I will be working on dummy coding the type and year columns.
#
# I want to analyze if there's a relationship between the date and the price of avocados. I want to see if avocados are more expensive during certain time periods of the year. I plan to do a linear regresssion with the "date" and "cost of price" variable to see if there's a positive correlation between the two. I will do an analysis for each year: 2015, 2016, 2017, and 2018 to see if it stays the same every year.

# %% [markdown]
# ***************
# ***************
# # **Analysis section**
#
# *Provide relevant pseudocode for linear regression or classification*

# %%
# Machine Learning 1

# %%
# Machine Learning 2, if needed

# %% [markdown]
# ***************
# ***************
# # **Conclusions**
#
# *Describe what you found and learned from your evaluation of your dataset*
